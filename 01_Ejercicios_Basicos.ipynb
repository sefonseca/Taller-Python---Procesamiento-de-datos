# %% [markdown]
# <a href="https://colab.research.google.com/github/sefonseca/Taller-Python---Procesamiento-de-datos/blob/main/01_Ejercicios_Basicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller 1 - Cadenas en Python
#
# **Nombre:** Sebastián Fonseca Doncel
#
# **Documento:** 1013259073
#
# **Asignatura:** Procesamiento de Datos a Gran Escala
#
# **Fecha:** 9/08/2026
#
# ## Ejercicio 1
#
# ¿Cual es el valor de la variable A después de ejecutar el siguiente código?

# %%
A = "1"

print(A)
# Out:
# 1

# %% [markdown]
# ### Explicación
#
# La variable A almacena una cadena de texto en este caso con el valor de "1".

# %% [markdown]
# ## Ejercicio 2
#
# ¿Cual es el valor de la variable B después de ejecutar el siguiente código?

# %%
B = "2"

print(B)
# Out:
# 2

# %% [markdown]
# ### Explicación
#
# La variable B contiene la cadena con valor "2".
#
# ## Ejercicio 3
#
# ¿Cual es el valor de la variable C después de ejecutar el siguiente código?

# %%
A = "1"
B = "2"

C = A + B

print(C)
# Out:
# 12

# %% [markdown]
# ### Explicación
#
# Como se indico en las explicaciones es posible concatenar dos cadenas. En este ejercicio se utiliza el operador de suma "+" para unir ambas cadenas en la variabel C.
#
# ## Ejercicio 4
#
# En la variable D haz uso del slicing para imprimir solo los primeros tres elementos.

# %%
D = "ABCDEFG"

print(D[:3])
# Out:
# ABC

# %% [markdown]
# ### Explicación
#
# Se extraen los primeros caracteres utilizando slicing.
#
# ##Ejercicio 5
#
# Usa un valor de stride de 2 para imprimir cada segundo elemento de la cadena E

# %%
E = "clocrkr1e1c1t"

print(E[::2])
# Out:
# correct

# %% [markdown]
# ### Explicación
#
# Se toman caracteres cada dos posiciones para reconstruir la palabra utilzando un stride en 2.
#
# ## Ejercicio 6
#
# Imprimir una barra invertida.

# %%
print("\\")
# Out:
# \

# %% [markdown]
# ##Explicación
#
# Para mostrar una barra invertida se utiliza `\\` dentro de la cadena
#
# ## Ejercicio 7
#
# Convierte en mayúsculas el contenido de la variable F

# %%
F = "You are wrong"

print(F.upper())
# Out:
# YOU ARE WRONG

# %% [markdown]
# ##Explicación
#
# Se utiliza el método `upper()` sobre la variable `F`,este método
# convierte las letras minúsculas de la cadena en mayúsculas y devuelve
# el nuevo resultado
#
# ## Ejercicio 8
#
# En la variable G, encuentra el primer índice de la sub-cadena snow

# %%
G = "Mary had a little lamb Little lamb, little lamb Mary had a little lamb \
Its fleece was white as snow And everywhere that Mary went Mary went, Mary went \
Everywhere that Mary went The lamb was sure to go"

print(G.find("snow"))
# Out:
# 95

# %% [markdown]
# ##Explicación
#
# Haciendo uso de la operacion find encontramos el primer indice de la sub cadena snow
#
# ## Ejercicio 9
#
# En la variable G, reemplaza la sub-cadena Mary con Bob

# %%
G = "Mary had a little lamb Little lamb, little lamb Mary had a little lamb \
Its fleece was white as snow And everywhere that Mary went Mary went, Mary went \
Everywhere that Mary went The lamb was sure to go"

print(G.replace("Mary", "Bob"))
# Out:
# Bob had a little lamb Little lamb, little lamb Bob had a little lamb Its fleece was white as snow And everywhere that Bob went Bob went, Bob went Everywhere that Bob went The lamb was sure to go

# %% [markdown]
# ##Explicación
#
# Usando la operacion replace remplazamos el nombre Mary por Bob
#
# ## Conclusiones
#
# Durante el desarrollo del laboratorio se practicaron las principales operaciones con cadenas en Python. Los ejercicios permitieron comprender el uso de indexación, slicing, concatenación y métodos de búsqueda y modificación de texto.
